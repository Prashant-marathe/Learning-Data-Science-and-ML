# %% [markdown]
# ##### 5 Number Summary
#
# The 5-number summary is a quick statistical description of a dataset.
#
# It tells you the spread and distribution without looking at the whole data.
#
# It includes these 5 values:
#
# 1. **Minimum** -- the smallest number
#
# 2. **Q1 (First Quartile)** -- 25% of the data is below this
#
# 3. **Median (Q2)** -- 50% point
#
# 4. **Q3 (Third Quartile)** -- 75% point
#
# 5. **Maximum** -- the largest number
#
# ##### Why is it useful?
#
# - Helps understand data distribution
#
# - Used to detect outliers
#
# - Used in boxplots
#
# - Works for any dataset size
#
# - Easy to compute and interpret.
#
# ##### Example:

# %%
import numpy as np

# %%
lst_marks = [45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74]
minimum, Q1, median, Q3, maximum = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence = Q1 - 1.5 * (IQR)
higher_fence = Q3 + 1.5 * (IQR)

# %%
lower_fence
# Out:
# np.float64(1.5)

# %%
higher_fence
# Out:
# np.float64(141.5)

# %%
import seaborn as sns

sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %% [markdown]
# Here, we didn't get any outliers as there are none. Let's try to box plot with outliers.

# %%
lst_marks = [-100, -200, 45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74, 150, 160, 165]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
